# %% [markdown]
# # **MICROSOFT STUDIO PROJECT**
#   **`PROJECT DONE BY: JENNIFER NJERI`**

# %% [markdown]
# ![WhatsApp Image 2023-07-24 at 17.44.16.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **OVERVIEW**

# %% [markdown]
# Founded on April 4, 1975, by Bill Gates and Paul Allen, Microsoft is a prominent multinational technology company renowned for its global impact and influence. With its headquarters in Redmond, Washington, USA, Microsoft stands among the largest and most influential technology corporations in the world.
#
# Specializing in the development, manufacturing, licensing, and support of software products and services, Microsoft's flagship achievement is the widely recognized operating system, Microsoft Windows. Embraced by a vast majority of personal computers worldwide, Microsoft's innovative technologies have left a profound mark on the digital landscape.

# %% [markdown]
# **PROBLEM STATEMENT**

# %% [markdown]
# Microsoft faces the challenge of entering the movie industry and establishing a new movie studio without prior experience in film production. They aim to capitalize on the success enjoyed by major companies producing original video content. To ensure their foray into filmmaking is strategically sound, they have enlisted our expertise to conduct an in-depth analysis of the most successful film types at the box office.
#
# Our task involves exploring datasets from reputable sources such as Box Office Mojo, IMDB, Rotten Tomatoes, TheMovieDB, and The Numbers. By extracting valuable insights from these datasets, we will generate actionable recommendations for the head of Microsoft's new movie studio. These recommendations will play a crucial role in guiding their decision-making process, helping them identify the most promising and commercially impactful film genres to pursue.

# %% [markdown]
# **`PROJECT OBJECTIVES`**
# 1. **Comprehensive Analysis of the Film Industry**: Conduct an in-depth study to gain a thorough understanding of the film industry's current landscape, trends, and key factors influencing success.
#
# 2. **Genre-based Analysis**: Explore and analyze data on genre ratings, popularity, and runtime to identify patterns and correlations that can provide insights into audience preferences and potential commercial viability.
#
# 3. **Profitability Assessment of Sequels**: Evaluate the profitability of producing film sequels by examining historical data on box office performance, production costs, and audience reception. Determine the factors that contribute to successful sequels and identify potential risks.
#
# 4. **Expert Crew Selection per Genre**: Develop a strategy for selecting experienced and skilled crew members tailored to specific film genres. Investigate how the expertise of directors and writers can influence the success of projects in different genres.

# %% [markdown]
# Through this analysis, we aim to gain a comprehensive understanding of the distributions, relationships, and possible correlations between the variables present in the data. By exploring these key aspects, we can uncover valuable insights and patterns that will facilitate informed decision-making and enhance our understanding of the underlying data trends in the film industry.

# %% [markdown]
# #**DATA UNDERSTANDING**

# %%
# Import necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #**`Comprehensive Analysis of the Film Industry`**

# %% [markdown]
# **DATASET ONE: bom.movie_gross.csv**

# %%
# Read 'bom.movie_gross.csv' and explore the overview of the data set

bom_gross_df = pd.read_csv('/content/bom.movie_gross.csv')
bom_gross_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
# Understand the structure of bom_gross_df
print('Shape of bom_gross_df:', bom_gross_df.shape)

bom_gross_df.info()
# Out:
# Shape of bom_gross_df: (3387, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %% [markdown]
# **Observation:**
#
# * The bom_gross_df has 3387 rows and 5 columns. Some columns have missing values, the columns with missing values are studio, domestic_gross and foreign_gross. The year column is in integer format instead of date format and foreign gross is in string format instead of float format.

# %%
# Find the percentage of missing values in bom_gross_df
bom_gross_df.isna().sum() / len(bom_gross_df) * 100
# Out:
# title              0.000000
# studio             0.147623
# domestic_gross     0.826690
# foreign_gross     39.858282
# year               0.000000
# dtype: float64

# %% [markdown]
# **Observation:**
# * The dataset contains missing values in multiple columns, with "foreign_gross" having the highest percentage of missing data at 39.86%. In contrast, the "title," "studio," and "year" columns have relatively low or zero percentages of missing values.

# %% [markdown]
# #**Handling missing values:**
#
# 1. Studio and domestic_gross have a negligible percentage of missing values. Dropping the rows that have the missing values in those columns is ideal.
#
# 2. Foreign_gross has 39.8% missing values, making it important due to its contribution to total movie revenues. As the percentage is high, dropping rows is not feasible; we'll replace missing values with measures of central tendency, considering outliers to determine the appropriate statistical method.

# %% [markdown]
# **1. Clean entries in studio and domestic_gross columns**:
#
# ---

# %%
# Drop NaN rows in Studio and Domestic_gross columns and confirm the drop
bom_gross_df = bom_gross_df.dropna(subset= ['studio' , 'domestic_gross'])
bom_gross_df.isna().sum()
# Out:
# title                0
# studio               0
# domestic_gross       0
# foreign_gross     1349
# year                 0
# dtype: int64

# %%
# Check for whitespaces and commas in studio column
print('Number of values with commas:', bom_gross_df['studio'].str.contains(',', regex=True). sum())
print('Number of values with whitespaces:', bom_gross_df['studio'].str.contains(' ', regex=True). sum())

# Remove whitespaces in studio column
bom_gross_df['studio'] = bom_gross_df['studio'].str.replace(' ', '')
print('Number of values with whitespaces after correction:', bom_gross_df['studio'].str.contains(' ', regex=True). sum())
# Out:
# Number of values with commas: 0
# Number of values with whitespaces: 58
# Number of values with whitespaces after correction: 0

# %% [markdown]
# **2. Deal with missing values in foreign_gross column**

# %%
# Check for whitespaces and commas
print('Number of values with commas:', bom_gross_df['foreign_gross'].str.contains(',', regex=True). sum())
print('Number of values with whitespaces:', bom_gross_df['foreign_gross'].str.contains(' ', regex=True). sum())

# Remove the commas
bom_gross_df['foreign_gross'] = bom_gross_df['foreign_gross'].str.replace(',', '')
print('Number of values with commas after correction:' , bom_gross_df['foreign_gross'].str.contains(',', regex=True). sum())
# Out:
# Number of values with commas: 5
# Number of values with whitespaces: 0
# Number of values with commas after correction: 0

# %%
# Convert foreign_gross to float format and confirm changes
bom_gross_df['foreign_gross'] = bom_gross_df['foreign_gross'].astype(float)
bom_gross_df['foreign_gross'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 3356 entries, 0 to 3386
# Series name: foreign_gross
# Non-Null Count  Dtype
# --------------  -----
# 2007 non-null   float64
# dtypes: float64(1)
# memory usage: 52.4 KB

# %% [markdown]
# **3. Identify outliers (if any)**

# %%
# Calculate the quartiles
Q1 = bom_gross_df['foreign_gross'].quantile(0.25)
Q3 = bom_gross_df['foreign_gross'].quantile(0.75)

# Calculate the interquartile range (IQR)
IQR = Q3 - Q1

# Set the lower and upper fence for outlier detection
lower_fence = Q1 - (1.5 * IQR)
upper_fence = Q3 + (1.5 * IQR)

print('lower_fence =' , lower_fence)
print('upper_fence =', upper_fence)

# Find number of entries with outliers
bomgross_outliers = bom_gross_df[(bom_gross_df['foreign_gross'] < lower_fence) |
              (bom_gross_df['foreign_gross'] > upper_fence)]
print('Number of entries with outliers:' , len(bomgross_outliers))
# Out:
# lower_fence = -104175000.0
# upper_fence = 184025000.0
# Number of entries with outliers: 256

# %%
# Visualization of the outliers
plt.figure(figsize=(8, 6))
sns.boxplot(y=bom_gross_df['foreign_gross'])
plt.title('Boxplot of Foreign Gross')
plt.ylabel('Amount')
plt.xlabel('Foreign Gross Column')
plt.show();

# %% [markdown]
# **Observation:**
#
# * The 'foreign_gross' column represents movie revenue, and its expected diversity makes the presence of outliers likely, reflecting extreme revenue values. Preserving these outliers is crucial to maintaining data integrity and gaining a comprehensive understanding of revenue distribution in the movie industry.
#
# * After detecting 256 outliers in the 'foreign_gross' column, I opted to use the median as the measure of central tendency for imputing missing values. This decision was driven by the median's resilience to extreme values, making it the most suitable choice in this context.

# %% [markdown]
# **4. Dealing with the missing values in foreign_gross column**

# %%
# Fill missing values with the median and confirm there are no missing values

median_value = bom_gross_df['foreign_gross'].median()

# Fill missing values
bom_gross_df['foreign_gross'] = bom_gross_df['foreign_gross'].fillna(median_value)

print('Current missing values:' , bom_gross_df['foreign_gross'].isna().sum())
# Out:
# Current missing values: 0

# %% [markdown]
# ##**Checking for duplicates in the dataset**

# %% [markdown]
# Now that I have cleaned the numerical data, my next step is to check for duplicates in the dataset. It is crucial to identify which movie entries have been repeated. If any duplicates are found, I will examine them and proceed to clean the categorical data.

# %%
# Check for duplicates in the dataset
duplicated = bom_gross_df.duplicated().sum()
duplicated
# Out:
# 0

# %% [markdown]
# **Observation:**
# * There are no duplicates in the dataset.

# %% [markdown]
# **Checking for duplicates in the titles column**
#
# * While the dataset as a whole contains no duplicate values, studios often release sequels or vintage versions of movies tailored to the current audience. To ensure accuracy, we must cross-reference and identify newer releases by checking for duplicate values in the 'title' column.

# %%
# Check for duplicates
duplicates = bom_gross_df.duplicated(subset=['title'])
print('Number of duplicate values:' , duplicates.sum())

# Examine duplicate entries
duplicate_entries = bom_gross_df[bom_gross_df.duplicated(subset=['title'], keep=False)]
duplicate_entries
# Out:
# Number of duplicate values: 1
#           title  studio  domestic_gross  foreign_gross  year
# 317   Bluebeard  Strand         33500.0         5200.0  2010
# 3045  Bluebeard   WGUSA         43100.0     19400000.0  2017

# %% [markdown]
# **Observation:**
# * It seems like Bluebeard has duplicate values with different studios, domestic gross, foreign gross, and release years. We can assume these are multiple releases or different versions of the movie over time. We shall keep this in mind while analysing data this dataset.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ##**Analysis of the market structure**
#
# Here, I wanted to understand the market structure by finding out:
#   1. Which studios have the largest market share in terms of revenue generated?
#   2. Which studios have the largest market share in terms of number of movies produced?
#   3. Is there a correlation between the number of movies produced and total_revenue?
#   4. Visualize the difference between the two market share dynamics for the top ten studios in each category. Is there a difference?

# %% [markdown]
# ###**`1. Which studios have the largest market share in terms of revenue generated?`**

# %%
# Find the total revenue generated per movie
bom_gross_df['total_revenue'] = bom_gross_df['domestic_gross'] + bom_gross_df['foreign_gross']
bom_gross_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year  total_revenue
# 0    652000000.0  2010   1.067000e+09
# 1    691300000.0  2010   1.025500e+09
# 2    664300000.0  2010   9.603000e+08
# 3    535700000.0  2010   8.283000e+08
# 4    513900000.0  2010   7.526000e+08

# %%
# Find total revenue generated per studio
studio_revenue_df = bom_gross_df.groupby('studio')['total_revenue'].sum().reset_index()
studio_revenue_df
# Out:
#     studio  total_revenue
# 0       3D   1.600000e+07
# 1      A23   3.896420e+07
# 2      A24   1.144656e+09
# 3      ADC   3.904820e+07
# 4       AF   8.324290e+07
# ..     ...            ...
# 250     XL   3.925800e+07
# 251    YFG   2.050000e+07
# 252   Yash   4.401921e+08
# 253    Zee   1.671000e+06
# 254  Zeit.   2.393635e+08
#
# [255 rows x 2 columns]

# %% [markdown]
# **Observation:**
# * There are 255 studios, I need to get the top 10 studios in the market.

# %%
# Find top 10 studios
studio_revenue_df = studio_revenue_df.sort_values(by='total_revenue', ascending=False)
top_ten_studios = studio_revenue_df.head(10)
top_ten_studios
# Out:
#      studio  total_revenue
# 36       BV   4.425168e+10
# 93      Fox   3.104417e+10
# 244      WB   3.102995e+10
# 236    Uni.   2.981536e+10
# 213    Sony   2.248252e+10
# 183    Par.   1.968506e+10
# 245  WB(NL)   1.035410e+10
# 134     LGF   8.885583e+09
# 133    LG/S   5.509524e+09
# 170    P/DW   5.076500e+09

# %%
# Plot a barchart showing the total revenue for the top ten studios
plt.figure(figsize=(10, 8))
plt.bar(top_ten_studios['studio'], top_ten_studios['total_revenue'])
plt.xlabel('Studio')
plt.ylabel('Total Revenue')
plt.title('TOP TEN STUDIOS WITH THE LARGEST MARKETSHARE')
plt.show();

# %% [markdown]
# **Observation:**
# * Disney's Buena Vista studio dominates the market with the largest market share, significantly surpassing all other studios. Fox Pictures, Warner Bros, and Universal Studios are in a closely contested race for the second-best position. Sony and Paramount Pictures secure the third position.

# %% [markdown]
# **Finding the exact percentage market shares of the top 10 studios**

# %%
# Find the sum of entire total revenue
sum_total_revenue = bom_gross_df['total_revenue'].sum()

# Find the percentage market share of the top ten studios
top_ten_studios['percentage_marketshare'] = (top_ten_studios['total_revenue']/sum_total_revenue) * 100
top_ten_studios
# Out:
# <ipython-input-18-b2fb097cc8d9>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_ten_studios['percentage_marketshare'] = (top_ten_studios['total_revenue']/sum_total_revenue) * 100
#      studio  total_revenue  percentage_marketshare
# 36       BV   4.425168e+10               16.100947
# 93      Fox   3.104417e+10               11.295400
# 244      WB   3.102995e+10               11.290227
# 236    Uni.   2.981536e+10               10.848301
# 213    Sony   2.248252e+10                8.180250
# 183    Par.   1.968506e+10                7.162395
# 245  WB(NL)   1.035410e+10                3.767333
# 134     LGF   8.885583e+09                3.233014
# 133    LG/S   5.509524e+09                2.004637
# 170    P/DW   5.076500e+09                1.847081

# %% [markdown]
# **Observation:**
#
# 1. BV (Buena Vista by Disney):
#     Total Revenue - $44.25 billion, Percentage Market Share - 16.10%
# 2. Fox: Total Revenue - $31.04 billion, Percentage Market Share - 11.30%
# 3. WB (Warner Bros):
#     Total Revenue - $31.03 billion, Percentage Market Share - 11.29%
# 4. Uni. (Universal Studios):
#     Total Revenue - $29.82 billion, Percentage Market Share - 10.85%
# 5. Sony:
#     Total Revenue - $22.48 billion, Percentage Market Share - 8.18%
# 6. Par. (Paramount Pictures):
#     Total Revenue - $19.69 billion, Percentage Market Share - 7.16%

# %% [markdown]
# ##**`2. Which studios have produced the most movies?`**

# %%
# Find number of movies released per studio
movies_per_studio = bom_gross_df['studio'].value_counts()
movies_per_studio
# Out:
# IFC           166
# Uni.          147
# WB            140
# Magn.         136
# Fox           136
#              ...
# TVC             1
# E1              1
# ELS             1
# PalT            1
# Synergetic      1
# Name: studio, Length: 255, dtype: int64

# %%
# View the value counts with the total revenue and arrange in descending order
nummovies_vs_revenue = pd.DataFrame({
    'num_movies': movies_per_studio,
    'total_revenue': bom_gross_df.groupby('studio')['total_revenue'].sum()
})
nummovies_vs_revenue = nummovies_vs_revenue.sort_values(by='num_movies', ascending=False).reset_index()
nummovies_vs_revenue
# Out:
#      index  num_movies  total_revenue
# 0      IFC         166   2.412592e+09
# 1     Uni.         147   2.981536e+10
# 2       WB         140   3.102995e+10
# 3      Fox         136   3.104417e+10
# 4    Magn.         136   2.140088e+09
# ..     ...         ...            ...
# 250   EXCL           1   1.971900e+07
# 251    FEF           1   2.001300e+07
# 252  FInd.           1   6.080000e+05
# 253    PDF           1   1.941170e+07
# 254     3D           1   1.600000e+07
#
# [255 rows x 3 columns]

# %%
# Rename index to studios
nummovies_vs_revenue.rename(columns = {'index': 'studios'}, inplace = True)
nummovies_vs_revenue
# Out:
#     studios  num_movies  total_revenue
# 0       IFC         166   2.412592e+09
# 1      Uni.         147   2.981536e+10
# 2        WB         140   3.102995e+10
# 3       Fox         136   3.104417e+10
# 4     Magn.         136   2.140088e+09
# ..      ...         ...            ...
# 250    EXCL           1   1.971900e+07
# 251     FEF           1   2.001300e+07
# 252   FInd.           1   6.080000e+05
# 253     PDF           1   1.941170e+07
# 254      3D           1   1.600000e+07
#
# [255 rows x 3 columns]

# %%
# Top 10 studios by number of movies produced

top10_by_nummovies = nummovies_vs_revenue.head(10)
top10_by_nummovies
# Out:
#   studios  num_movies  total_revenue
# 0     IFC         166   2.412592e+09
# 1    Uni.         147   2.981536e+10
# 2      WB         140   3.102995e+10
# 3     Fox         136   3.104417e+10
# 4   Magn.         136   2.140088e+09
# 5     SPC         123   2.640437e+09
# 6    Sony         109   2.248252e+10
# 7      BV         106   4.425168e+10
# 8     LGF         102   8.885583e+09
# 9    Par.         101   1.968506e+10

# %%
# Plot a bar chart of the top ten movies in terms of number of movies
plt.figure(figsize=(10, 8))
plt.bar(top10_by_nummovies['studios'], top10_by_nummovies['num_movies'], color='skyblue')
plt.xlabel('Studio')
plt.ylabel('Number of Movies')
plt.title('Top Ten Studios with the Largest Number of Movies')
plt.xticks(rotation=45)
plt.show();

# %% [markdown]
# **Observation:**
# * The top producing studio is IFC followed by Universal Studios(Uni.) and Warner Bros. There is not much of a variance in the production of movies among the top ten studios.

# %% [markdown]
# ##**`3. Is there a correlation between the number of movies produced and total_revenue?`**

# %%
# Find the correlation between number of movies and total revenue generated
correlation = nummovies_vs_revenue['num_movies'].corr(nummovies_vs_revenue['total_revenue'])

print("Correlation between number of movies produced and total revenue:", correlation)
# Out:
# Correlation between number of movies produced and total revenue: 0.6970852683415834

# %% [markdown]
# **Observation:**
# * The correlation coefficient of 0.697 indicates a moderately strong positive relationship where a majority of studios with highest returns produced more movies.
#
# Let's visualize this.

# %%
# Plot a scatter plot to visualise this correlation
plt.figure(figsize=(8, 6))
plt.scatter(nummovies_vs_revenue['num_movies'], nummovies_vs_revenue['total_revenue'], alpha=0.6)
plt.xlabel('Number of Movies Produced')
plt.ylabel('Total Revenue')
plt.title('Correlation between Number of Movies and Total Revenue')
plt.grid(True)
plt.show();

# %% [markdown]
# **Observation:**
# * Here we see that a majority of studios that released less than 100 movies have had a total revenue of less that 10 billion dollars.
# * Only 4 studios that produced more than 100 movies remained in the under 10 billion dollars mark.
# * It is important to note than only 6 studios that produced more than 100 movies had a revenue significantly greater that 10 billion dollars.

# %% [markdown]
# ##**`4. Visualize the difference between the two market share dynamics for the top ten studios in each category. Is there a difference?`**

# %%
# Plot two bar charts to visualize this comparison
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Plot of top ten studios by total revenue
ax1.barh(top_ten_studios['studio'], top_ten_studios['total_revenue'], color='skyblue')
ax1.set_xlabel('Total Revenue')
ax1.set_ylabel('Studio')
ax1.set_title('Top 10 Studios per Total Revenues')
ax1.grid(True)

# Plot of top ten studios by number of movies produced
ax2.barh(top10_by_nummovies['studios'], top10_by_nummovies['num_movies'], color='salmon')
ax2.set_xlabel('Number of movies')
ax1.set_ylabel('Studio')
ax2.set_title('Top 10 Movie Studios per Number of Movies')
ax2.grid(True)

plt.tight_layout()
plt.show();

# %% [markdown]
# **Observation:**
#
# * A majority of movies appear in both charts but it is important to note that despite IFC being the highest in movie production, they do not appear in the top 10 total revenue. BV on the other hand has 16% market share in revenue but comes in 7th position in number of movies produced.
# * WB(NL), LG/S and P/DW are among the top ten movies in terms of revenue but do not make an appearance in the top ten studios in terms of movies generated.
# * Whereas; SPC, Magn. and IFC do not appear in the top ten market share in terms of revenue despite them being among the top ten movie studios to generate movies.
#
# This is an indication that a studio does not really have to generate more movies to have more revenue.

# %% [markdown]
# ##**Profitability Assessment of Sequels**

# %% [markdown]
# **DATASET TWO: tn.movie_budgets.csv**

# %%
# Read 'tn.movie_budgets.csv' and explore the overview of the dataframe
movie_budgets_df = pd.read_csv('/content/tn.movie_budgets.csv')
movie_budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
# Understand the structure of movie_budgets_df
print('Shape of movie_budgets_df:', movie_budgets_df.shape)

movie_budgets_df.info()
# Out:
# Shape of movie_budgets_df: (5782, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %% [markdown]
# **Observation:**
#
# * The movie_budgets_df has a total of 5782 rows and 6 columns. There are no missing values in the dataframe.
# * However, before proceeding with any analysis, it is necessary to convert the budget and revenue columns ('production_budget', 'domestic_gross', 'worldwide_gross') to a float datatype for further calculations and analysis.
# * The aforementioned columns contain dollar signs ($) and commas (,) that need to be cleaned before converting the values to numeric data types.
# * Additionally, the 'release_date' column needs to be converted to a datetime data type to facilitate temporal analysis.

# %% [markdown]
# **`1. Clean 'production_budget', 'domestic_gross', 'worldwide_gross' columns`**

# %%
# Remove '$' and ',' in the 'production_budget' column and convert to float
movie_budgets_df['production_budget'] = movie_budgets_df['production_budget'].replace({'\$': '', ',': ''}, regex=True).astype(float)

# Remove '$' and ',' in the 'domestic_gross' column and convert to float
movie_budgets_df['domestic_gross'] = movie_budgets_df['domestic_gross'].replace({'\$': '', ',': ''}, regex=True).astype(float)

# Remove '$' and ',' in the 'worldwide_gross' column and convert to float
movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].replace({'\$': '', ',': ''}, regex=True).astype(float)

# Confirm changes
movie_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   float64
#  4   domestic_gross     5782 non-null   float64
#  5   worldwide_gross    5782 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 271.2+ KB

# %% [markdown]
# **`2. Clean release_date column`**

# %%
# Convert 'release_date' column to date datatype and confirm changes
movie_budgets_df['release_date'] = pd.to_datetime(movie_budgets_df['release_date'])
movie_budgets_df['release_date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5782 entries, 0 to 5781
# Series name: release_date
# Non-Null Count  Dtype
# --------------  -----
# 5782 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 45.3 KB

# %% [markdown]
# **`3. Clean 'movie' column`**

# %%
# Check for whitespaces in movie column
print('Number of values with whitespaces:', movie_budgets_df['movie'].str.contains(' ', regex=True). sum())

# Remove whitespaces in movie column
movie_budgets_df['movie'] = movie_budgets_df['movie'].str.replace(' ', '')
print('Number of values with whitespaces after correction:', movie_budgets_df['movie'].str.contains(' ', regex=True). sum())
# Out:
# Number of values with whitespaces: 4519
# Number of values with whitespaces after correction: 0

# %%
# Check for duplicates in movie_budgets_df
movie_budgets_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Observation:
#
# * There are no duplicate values in the dataset.
# * To ensure accuracy, we must cross-reference and identify newer releases by checking for duplicate values in the 'movie' column.

# %%
# Check for duplicates
duplicated_values = movie_budgets_df.duplicated(subset=['movie'])
num_duplicates = duplicated_values.sum()
print("Number of duplicate values:", num_duplicates)

# Examine duplicate entries
duplicate_entries = movie_budgets_df[duplicated_values]
duplicate_entries.head()
# Out:
# Number of duplicate values: 84
#      id release_date          movie  production_budget  domestic_gross  \
# 273  74   1998-05-19       Godzilla        125000000.0     136314294.0
# 408   9   2018-11-21      RobinHood         99000000.0      30824628.0
# 484  85   2005-07-08  FantasticFour         87500000.0     154696080.0
# 543  44   1999-05-07       TheMummy         80000000.0     155385488.0
# 707   8   1997-06-13       Hercules         70000000.0      99112101.0
#
#      worldwide_gross
# 273      376000000.0
# 408       84747441.0
# 484      333132750.0
# 543      416385488.0
# 707      250700000.0

# %% [markdown]
# Observation:
#
# * The output indicates that there are 83 duplicate values in the 'movie' column with different release dates.
# * Is releasing newer versions of vintage movies a viable business opportunity?
# * We can use these duplicates to assess the changes in production_budget, domestic_gross and foreign gross for each movie that was release multiple times.

# %% [markdown]
# **Analyse the profitability of the production of sequels**

# %% [markdown]
# We start by pairing the duplicates together.

# %%
# Get the unique movie titles with a value count greater than one
duplicates_movie_sum = movie_budgets_df['movie'].value_counts()
titles_greater_than_one = duplicates_movie_sum[duplicates_movie_sum > 1].index

# Initialize an empty list to store values before conversion as a DataFrames
duplicate_entries_dfs = []

# Loop over each movie title with duplicate entries
for title in titles_greater_than_one:
    duplicate_entries_movie = movie_budgets_df[movie_budgets_df['movie'] == title]

    # Append the duplicate entries to the empty list
    duplicate_entries_dfs.append(duplicate_entries_movie)

# Concatenate the duplicate_entries_dfs into a single DataFrame
movies_duplicates_df = pd.concat(duplicate_entries_dfs)

# Display the combined df
movies_duplicates_df
# Out:
#       id release_date           movie  production_budget  domestic_gross  \
# 3014  15   2007-08-31       Halloween         15000000.0      58269151.0
# 3535  36   2018-10-19       Halloween         10000000.0     159342015.0
# 5536  37   1978-10-17       Halloween           325000.0      47000000.0
# 243   44   2015-03-27            Home        130000000.0     177397510.0
# 3455  56   2009-06-05            Home         12000000.0             0.0
# ...   ..          ...             ...                ...             ...
# 2610  11   2017-09-29      Flatliners         20000000.0      16883115.0
# 64    65   2017-06-09        TheMummy        195000000.0      80101125.0
# 543   44   1999-05-07        TheMummy         80000000.0     155385488.0
# 790   91   2016-08-12  PeteâsDragon         65000000.0      76233151.0
# 3566  67   1977-11-03  PeteâsDragon         10000000.0      36000000.0
#
#       worldwide_gross
# 3014       77514401.0
# 3535      254900667.0
# 5536       70000000.0
# 243       385997896.0
# 3455              0.0
# ...               ...
# 2610       45173738.0
# 64        409953905.0
# 543       416385488.0
# 790       137768975.0
# 3566       36000000.0
#
# [165 rows x 6 columns]

# %% [markdown]
# I will calculate total revenue by summing domestic and worldwide gross, then use it to determine the gross profit or loss for each movie by subtracting the production budget, all based on the release date.

# %%
# Find total_revenue and gross profit/loss of each movie in that has been released more than once
movies_duplicates_df['total_revenue'] = movies_duplicates_df['domestic_gross'] + movies_duplicates_df['worldwide_gross']
movies_duplicates_df['gross_profit/loss'] = movies_duplicates_df['total_revenue'] - movies_duplicates_df['production_budget']
movies_duplicates_df.head(12)
# Out:
#       id release_date                  movie  production_budget  \
# 3014  15   2007-08-31              Halloween         15000000.0
# 3535  36   2018-10-19              Halloween         10000000.0
# 5536  37   1978-10-17              Halloween           325000.0
# 243   44   2015-03-27                   Home        130000000.0
# 3455  56   2009-06-05                   Home         12000000.0
# 5459  60   2009-04-23                   Home           500000.0
# 39    40   2005-12-14               KingKong        207000000.0
# 2374  75   1976-12-17               KingKong         23000000.0
# 5396  97   1933-04-07               KingKong           672000.0
# 2873  74   2009-02-13          Fridaythe13th         17000000.0
# 5424  25   1980-05-09          Fridaythe13th           550000.0
# 3043  44   2009-03-13  TheLastHouseontheLeft         15000000.0
#
#       domestic_gross  worldwide_gross  total_revenue  gross_profit/loss
# 3014      58269151.0       77514401.0    135783552.0        120783552.0
# 3535     159342015.0      254900667.0    414242682.0        404242682.0
# 5536      47000000.0       70000000.0    117000000.0        116675000.0
# 243      177397510.0      385997896.0    563395406.0        433395406.0
# 3455             0.0              0.0            0.0        -12000000.0
# 5459         15433.0       44793168.0     44808601.0         44308601.0
# 39       218080025.0      550517357.0    768597382.0        561597382.0
# 2374      52614445.0       90614445.0    143228890.0        120228890.0
# 5396      10000000.0       10000650.0     20000650.0         19328650.0
# 2873      65002019.0       92670237.0    157672256.0        140672256.0
# 5424      39754601.0       59754601.0     99509202.0         98959202.0
# 3043      32752215.0       46526243.0     79278458.0         64278458.0

# %% [markdown]
# I'll calculate the changes in production budgets and profit/loss between the latest and oldest movie releases.

# %%
# Group the df by 'movie'
grouped_by_movie = movies_duplicates_df.groupby('movie' , group_keys=False)

# Calculate the budget difference and revenue difference for each duplicate movie
def calculate_differences(group):
    group = group.sort_values(by='release_date')
    group['budget_difference'] = group['production_budget'].iloc[-1] - group['production_budget'].iloc[0]
    group['gross_profit/loss_difference'] = group['gross_profit/loss'].iloc[-1] - group['gross_profit/loss'].iloc[0]
    return group

duplicates_difference_df = grouped_by_movie.apply(calculate_differences)

duplicates_difference_df.head(6)
# Out:
#       id release_date                     movie  production_budget  \
# 5614  15   1916-12-24  20,000LeaguesUndertheSea           200000.0
# 4270  71   1954-12-23  20,000LeaguesUndertheSea          5000000.0
# 5016  17   1984-11-09     ANightmareonElmStreet          1800000.0
# 1648  49   2010-04-30     ANightmareonElmStreet         35000000.0
# 2032  33   1992-11-11                   Aladdin         28000000.0
# 80    81   2019-05-24                   Aladdin        182000000.0
#
#       domestic_gross  worldwide_gross  total_revenue  gross_profit/loss  \
# 5614       8000000.0        8000000.0     16000000.0         15800000.0
# 4270      28200000.0       28200000.0     56400000.0         51400000.0
# 5016      25504513.0       25504513.0     51009026.0         49209026.0
# 1648      63075011.0      117729621.0    180804632.0        145804632.0
# 2032     217350219.0      504050219.0    721400438.0        693400438.0
# 80       246734314.0      619234314.0    865968628.0        683968628.0
#
#       budget_difference  gross_profit/loss_difference
# 5614          4800000.0                    35600000.0
# 4270          4800000.0                    35600000.0
# 5016         33200000.0                    96595606.0
# 1648         33200000.0                    96595606.0
# 2032        154000000.0                    -9431810.0
# 80          154000000.0                    -9431810.0

# %% [markdown]
# **Observation:**
# * The differences in profit and budget replicate throughout the dataset. Cleaning the data will enable a more accurate and comprehensive analysis of profit and budget changes for each movie across different releases.

# %%
# Grouping the dataset and creating a new df
duplicates_differences = duplicates_difference_df.groupby(by = 'movie')['gross_profit/loss'].diff()
duplicates_differences

budget_differences = duplicates_difference_df.groupby(by = 'movie')['production_budget'].diff()
budget_differences

duplicates_differences = pd.DataFrame({
    'movie' : duplicates_difference_df['movie'],
    'gross_profit/loss_difference': duplicates_differences,
    'budget_differences': budget_differences
})

duplicates_differences.head()
# Out:
#                          movie  gross_profit/loss_difference  \
# 5614  20,000LeaguesUndertheSea                           NaN
# 4270  20,000LeaguesUndertheSea                    35600000.0
# 5016     ANightmareonElmStreet                           NaN
# 1648     ANightmareonElmStreet                    96595606.0
# 2032                   Aladdin                           NaN
#
#       budget_differences
# 5614                 NaN
# 4270           4800000.0
# 5016                 NaN
# 1648          33200000.0
# 2032                 NaN

# %%
# Remaining with one entry per movie by deleting missing values
duplicates_differences = duplicates_differences.dropna(how = 'any')
duplicates_differences
# Out:
#                          movie  gross_profit/loss_difference  \
# 4270  20,000LeaguesUndertheSea                  3.560000e+07
# 1648     ANightmareonElmStreet                  9.659561e+07
# 80                     Aladdin                 -9.431810e+06
# 50           AliceinWonderland                  1.162682e+09
# 340     AroundtheWorldin80Days                 -9.199168e+07
# ...                        ...                           ...
# 2970                    Trance                  9.866645e+06
# 1588                  Twilight                  5.479398e+08
# 3403             Unforgettable                  2.862164e+07
# 1420                   Unknown                  1.601280e+08
# 302                      Venom                  9.743765e+08
#
#       budget_differences
# 4270           4800000.0
# 1648          33200000.0
# 80           154000000.0
# 50           197000000.0
# 340          104000000.0
# ...                  ...
# 2970          15050000.0
# 1588          17000000.0
# 3403          -6000000.0
# 1420          36300000.0
# 302           91000000.0
#
# [84 rows x 3 columns]

# %% [markdown]
# We can perform statistical analysis to test the profitability of releasing newer versions of movies.

# %%
# Calculate the mean profit/loss change
mean_profit_loss_change = duplicates_differences['gross_profit/loss_difference'].mean()

print(f"Mean Profit/Loss Change: {mean_profit_loss_change}")

# Calculate the median profit/loss change
median_profit_loss_change = duplicates_differences['gross_profit/loss_difference'].median()

print("Median Profit/Loss Change:", median_profit_loss_change)
# Out:
# Mean Profit/Loss Change: 108472292.60714285
# Median Profit/Loss Change: 13232947.5

# %% [markdown]
# **Observation:**
#
# * The mean profit/loss change of approximately $108,472,292.60 indicates that, on average, the gross profit/loss of movies increases by this amount between their initial release and most recent release.
#
# * The mean is affected by outliers so to cater for outliers, we used the median as a measure of central tendancy to find the middle point of profit/loss changes.
#
#
# * The dataset shows a positive mean/median profit/loss change, indicating a general increase in gross profit between a movie's initial and most recent release. This suggests potential profitability for studios like Microsoft in re-releasing vintage movies with updated versions, as audiences seem receptive to revisiting these classics.

# %%
# Find the mean changes in budget
mean_budget_change = duplicates_differences['budget_differences'].mean()
mean_budget_change
# Out:
# 41151796.39285714

# %% [markdown]
# **Observation:**
# * On average studios spent an aditional $41,151,796 from the previous budget.

# %%
# Plot a line graph showing the deffirences in budget and gross profit in production of sequels
plt.figure(figsize=(8, 6))
plt.plot(duplicates_differences['movie'], duplicates_differences['budget_differences'], label='Budget', marker='o')
plt.plot(duplicates_differences['movie'], duplicates_differences['gross_profit/loss_difference'], label='Profit/Loss', marker='o')
plt.xlabel('Changes Per Sequel')
plt.ylabel('Amount (in dollars)')
plt.title('PROFITABILITY IN PRODUCTION OF SEQUELS')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add the mean lines
plt.axhline(mean_budget_change, color='red', linestyle='dashed', label='Budget Difference Mean')
plt.axhline(mean_profit_loss_change, color='green', linestyle='dashed', label='Profit/Loss Difference Mean')

# Legend
plt.legend()

# Remove each movie name on the x-axis
plt.xticks([])

plt.tight_layout()
plt.show();

# %% [markdown]
# **Observation:**
#
# * It appears to be profitable to re-release vintage movies. However, it's important to consider the cost implications of production. In this regard, we will examine the general additional cost implications between the initial release and the latest release, and determine if the budget difference directly affects the changes in profit/loss.
#
# * To investigate this, we will assess the relationship between the budget difference (i.e., the difference in production budget between the first and latest release) and the corresponding changes in profit/loss.
#
# * By analyzing this relationship, we can determine if there is a direct connection between the budget difference and the resulting profit/loss changes.

# %% [markdown]
# ---
#
#
#
# ---

# %%
# Find the correlation coefficient between budget_difference and revenue_difference
correlation_coefficient = duplicates_differences['budget_differences'].corr(duplicates_differences['gross_profit/loss_difference'])

print("Correlation Coefficient:",correlation_coefficient)
# Out:
# Correlation Coefficient: 0.5531551703701013

# %% [markdown]
# **Observation:**
#
# * The correlation coefficient of 0.553 indicates a moderate positive correlation between the budget_difference and profit difference.
# * The positive correlation coefficient implies that as the budget difference increases, the profit difference also tends to increase.
# * This means that movies with higher budget differences may have higher profit differences, indicating potential increased profitability.
#
# Let's visualize this correlation using a scatterplot.

# %%
# Plot a scatter plot between budget difference and gross profit/loss difference

plt.figure(figsize=(8, 6))
plt.scatter(duplicates_differences['budget_differences'], duplicates_differences['gross_profit/loss_difference'], alpha=0.6)
plt.xlabel('Budget Change')
plt.ylabel('Profit Change')
plt.title('Correlation between Budget Changes and Profit Changes')
plt.grid(True)
plt.show();

# %% [markdown]
# **Observation:**
#
# * The scatter plot demonstrates a positive correlation between budget differences and gross profit/loss differences, implying that movies with larger budget differences tend to have greater profit/loss variations between their earliest and latest releases.
# * However, the scattered distribution of data points suggests that the relationship between budget changes and profit/loss changes is not entirely linear, and other factors might influence the outcomes.
#
# * Outliers, located far from the main cluster, represent movies with atypical budget and profit/loss differences compared to the majority of the dataset.

# %% [markdown]
# Other factors like marketing, critical reception, genre, and audience demand should be considered in a comprehensive analysis. We will look into various datasets that include ratings, genre and producers to take this into account.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ##**Genre-based Analysis**

# %% [markdown]
# **`DATASET THREE & FOUR: imdb.title.ratings.csv.gz and imdb.title.basics.csv`**

# %%
# Read imdb.title.ratings.csv.gz dataset
title_ratings_df = pd.read_csv('/content/imdb.title.ratings.csv.gz')
title_ratings_df.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
# Understand the structure of title_ratings_df
title_ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# **Observation:**
#
# * IMDB definition of tconst is alphanumeric unique identifier of the title.

# %%
# Read imdb.title.basics.csv
title_basics_df = pd.read_csv('/content/imdb.title.basics.csv')
title_basics_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
# Understand the structure of title_basics_df
title_basics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %% [markdown]
# **Observation:**
#
# * The dataset title_basics_df includes extensive movie attributes like titles, release year, runtime, and genres. It complements title_ratings_df, which lacked movie names.
# * I'll join them based on the tconst key. However, title_basics_df has missing values in original_title, runtime_minutes, and genres. We'll address these missing values during the analysis of ratings per genres and runtime after joining the datasets.

# %% [markdown]
# *I shall work with movie_ratings_df going forward after the join.*

# %%
# Join title_basics_df and title_ratings_df and view the new df
movie_ratings_df = title_basics_df.merge(title_ratings_df, on='tconst', how='inner')
movie_ratings_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
movie_ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73856 entries, 0 to 73855
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           73856 non-null  object
#  1   primary_title    73856 non-null  object
#  2   original_title   73856 non-null  object
#  3   start_year       73856 non-null  int64
#  4   runtime_minutes  66236 non-null  float64
#  5   genres           73052 non-null  object
#  6   averagerating    73856 non-null  float64
#  7   numvotes         73856 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 5.1+ MB

# %%
# Find percentage of missing values
movie_ratings_df.isnull().mean() * 100
# Out:
# tconst              0.000000
# primary_title       0.000000
# original_title      0.000000
# start_year          0.000000
# runtime_minutes    10.317374
# genres              1.088605
# averagerating       0.000000
# numvotes            0.000000
# dtype: float64

# %% [markdown]
# **Observation:**
#
# * By imbd definition:
#   1. primaryTitle is the more popular title / the title used by the filmmakers on promotional materials at the point of release
#   2. originalTitle is original title, in the original language.
#
# * In movie_ratings_df, we have missing values in runtime_minutes and genres columns. We'll handle these missing values before conducting the analysis.
#
# * For genre, since there is no clear replacement criterion and the percentage of missing values is small, dropping them is the preferred approach. As for runtime missing values, we can replace them using the mean, median, or mode.

# %% [markdown]
# **`Clean genres column`**

# %%
# Drop missing values in genres and confirm drop
movie_ratings_df = movie_ratings_df.dropna(subset=['genres'])

print("Number of missing values in 'genres' column after dropping:", movie_ratings_df['genres'].isnull().sum())
# Out:
# Number of missing values in 'genres' column after dropping: 0

# %%
# Count unwanted special characters in genres column, if any remove them

commas_movie_ratings = movie_ratings_df['genres'].str.count(',')
whitespaces_movie_ratings = movie_ratings_df['genres'].str.count(' ')
numerals_movie_ratings = movie_ratings_df['genres'].str.count(r'\d').sum()

print("Number of commas in genres:", commas_movie_ratings.sum())
print("Number of whitespaces in genres:", whitespaces_movie_ratings.sum())
print("Number of numerals in genres:", numerals_movie_ratings)
# Out:
# Number of commas in genres: 55438
# Number of whitespaces in genres: 0
# Number of numerals in genres: 0

# %% [markdown]
# **Observation:**
#
# * Some movies have more than two genres that are separated by commas.So we shall not replace the commas.

# %%
# Check for duplicates
num_duplicates_in_genre = movie_ratings_df.duplicated(subset=['genres']).sum()
print("Number of duplicate entries in 'genres' column:", num_duplicates_in_genre)
# Out:
# Number of duplicate entries in 'genres' column: 72129

# %% [markdown]
# **Observation:**
#
# * The number of duplicates in genres indicates that a majority of the movies in the dataset have the same genre combinations.

# %% [markdown]
# **`Clean runtime_minutes column`**

# %% [markdown]
# **Observation:**
#
# * To handle missing values in the runtime_minutes column, I will fill them in based on the average runtime of the genres to which the movies belong.
#
# * This approach is more suitable as different genres tend to have varying runtimes. For example, Bollywood genres often have longer runtimes compared to others.

# %%
# Initial number of missing values
print('Missing values in runtime_minutes column before fill:' , movie_ratings_df['runtime_minutes'].isna().sum())

# Find the genres with missing values in runtime_minutes column
genres_with_missing_runtime = movie_ratings_df[movie_ratings_df['runtime_minutes'].isnull()]['genres'].unique()

# Calculate the average runtime for each genre
genre_avg_runtime = movie_ratings_df.groupby('genres')['runtime_minutes'].mean()

# Fill missing values with the mean of their respective genres
for genre in genres_with_missing_runtime:
    mean_runtime = genre_avg_runtime[genre]
    movie_ratings_df.loc[movie_ratings_df['genres'] == genre, 'runtime_minutes'] = movie_ratings_df.loc[movie_ratings_df['genres'] == genre, 'runtime_minutes'].fillna(mean_runtime)

print('Missing values in runtime_minutes column after fill:' , movie_ratings_df['runtime_minutes'].isna().sum())
# Out:
# Missing values in runtime_minutes column before fill: 7332
# Missing values in runtime_minutes column after fill: 19

# %%
# Drop rows with missing values in the runtime_minutes column
movie_ratings_df = movie_ratings_df.dropna(subset=['runtime_minutes'])

# Confirm dropped missing values
print('Missing values in runtime_minutes column after drop:' , movie_ratings_df['runtime_minutes'].isna().sum())
# Out:
# Missing values in runtime_minutes column after drop: 0

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# By understanding the factors that contribute to high ratings, we can gain insights into the elements that make a movie more appealing to both critics and audiences. This knowledge can be valuable for filmmakers and production companies, helping them create movies that have a higher chance of achieving critical acclaim and commercial success.

# %% [markdown]
# **Explore genre ratings, popularity and runtime**

# %% [markdown]
# On IMDb, a rating of around 7.0 or higher (out of 10) is generally considered quite good and indicative of a well-received movie. Here I shall see whether the length of the movie (runtime) or the number of votes generated an average rating of 7.0 and above. I will use a heatmap to visualise this correlation.

# %%
# Filter movies with average rating of 7 and above
high_rated_movies = movie_ratings_df[movie_ratings_df['averagerating'] >= 7]

# Calculate the correlation matrix
correlation_matrix = high_rated_movies[['runtime_minutes', 'averagerating', 'numvotes']].corr()

correlation_matrix
# Out:
#                  runtime_minutes  averagerating  numvotes
# runtime_minutes         1.000000      -0.081552  0.120927
# averagerating          -0.081552       1.000000 -0.029029
# numvotes                0.120927      -0.029029  1.000000

# %%
# Create a heatmap to visualize this correlation
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt='.2f')
plt.title('Correlation Heatmap for Movies with Average Rating of 7 and Above')
plt.show();

# %% [markdown]
# **Observation:**
#
# * There is a weak negative correlation of approximately -0.0815 between runtime_minutes and averagerating, indicating a slight tendency for longer runtime movies to have slightly lower average ratings. However, the relationship is not significant.
# * Averagerating and numvotes have a weak negative correlation of approximately -0.0290, suggesting that movies with higher average ratings tend to have slightly fewer votes. Again, the correlation is weak, indicating no strong relationship between average rating and the number of votes.
# * Runtime_minutes and numvotes have a weak positive correlation of approximately 0.1209, implying that longer runtime movies tend to have slightly more votes. However, the impact of runtime on the number of votes is not substantial, given the weak correlation.

# %% [markdown]
# **`Analyse genre combinations with ratings, runtime and num of votes`**

# %% [markdown]
# The analysis emphasizes weak correlations between movie runtime, average rating, and number of votes, leading to a focus on genres to identify the top 10 best-performing ones based on ratings, average runtime, and popularity, aiming to reveal key factors contributing to success across different genres.

# %% [markdown]
# Top 10 best performing genres in terms of ratings:

# %%
# Sort the genres based on their average rating in descending order
# Note that we have averaged average rating, not to worry since we are averaging the average rating per genre

best_performing_genres = movie_ratings_df.groupby('genres')['averagerating'].mean().sort_values(ascending=False)

# Create a bar chart for top 10 best performing genres in terms of average rating
plt.figure(figsize=(8, 6))
sns.barplot(x=best_performing_genres.head(10).values, y=best_performing_genres.head(10).index, palette='inferno')
plt.xlabel('Average Rating')
plt.ylabel('Genres')
plt.title('Top 10 Best Performing Genres in Terms of Ratings')
plt.xticks(rotation=0, ha='center')
plt.show();

# %% [markdown]
# **Observation:**
#
# * Besides the usual action, drama, comedy and thriller genres gannering high ratings over the years. There is unusual 'less fun' genres that have high ratings.
# * Documentaries, Reality TV, Biography, History and News genres have one thing in common: they tell the personal stories of individuals, highlighting their struggles, triumphs, and contributions.
# * These human stories can evoke strong emotions and create a powerful connection with viewers, leading to higher ratings.

# %% [markdown]
# Performance characteristics of top 10 genres in terms of runtime:

# %%
# Get the top 10 genres based on average ratings
top_10_genres = best_performing_genres.head(10).index

# Filter the movie_ratings_df to include only the top 10 genres
top_10_genres_df = movie_ratings_df[movie_ratings_df['genres'].isin(top_10_genres)]

# Calculate the average runtime for each genre
average_runtime_per_genre = top_10_genres_df.groupby('genres')['runtime_minutes'].mean().reset_index()

average_runtime_per_genre
# Out:
#                         genres  runtime_minutes
# 0     Action,Adventure,Musical             97.0
# 1              Adventure,Crime            100.0
# 2      Biography,History,Music             84.0
# 3   Comedy,Documentary,Fantasy             70.0
# 4   Documentary,Family,Musical             59.0
# 5  Documentary,News,Reality-TV             61.0
# 6       Documentary,News,Sport             85.0
# 7                  Drama,Short             18.0
# 8                    Game-Show            130.0
# 9        Mystery,News,Thriller             88.0

# %% [markdown]
# Let us visualize this data.

# %%
# Plot a bar chart of average runtime for each top performing genre combinations
plt.figure(figsize=(8, 6))
sns.barplot(data=average_runtime_per_genre, x='genres', y='runtime_minutes', palette='winter')
plt.xlabel('Genres')
plt.ylabel('Average Runtime (minutes)')
plt.title('Average Runtime Of Top 10 Genres')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='dashed')
plt.tight_layout()
plt.show();

# %% [markdown]
# **Observation:**
#
# * Game-Show has the longest average runtime (130 minutes), while Drama, Short has the shortest average runtime (18 minutes).
# * The data can help Microsoft Studio understand audience preferences and expectations regarding runtime in different genres.

# %% [markdown]
# Popularity of top 10 genre combination by estimate of average number of votes:

# %%
# Calculate the average number of votes for each genre
average_numvotes_per_genre = top_10_genres_df.groupby('genres')['numvotes'].mean().reset_index()

average_numvotes_per_genre
# Out:
#                         genres  numvotes
# 0     Action,Adventure,Musical      42.0
# 1              Adventure,Crime      15.0
# 2      Biography,History,Music       6.0
# 3   Comedy,Documentary,Fantasy       5.0
# 4   Documentary,Family,Musical      19.0
# 5  Documentary,News,Reality-TV       8.0
# 6       Documentary,News,Sport      25.0
# 7                  Drama,Short       8.0
# 8                    Game-Show       7.0
# 9        Mystery,News,Thriller      92.0

# %%
# Plot a bar chart of average runtime for each top performing genre combinations
plt.figure(figsize=(8, 6))
sns.barplot(data=average_numvotes_per_genre, x='genres', y='numvotes', palette='summer')
plt.xlabel('Genres')
plt.ylabel('Average numvotes (thousands)')
plt.title('Average Number of votes for Top 10 Genres')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='dashed')
plt.tight_layout()
plt.show();

# %% [markdown]
# **Observation:**
#
# * "Mystery, News, Thriller" has the highest average number of votes, indicating that it is the most popular genre combination among the top 10. On the other hand, genres like "Comedy, Documentary, Fantasy" and "Biography, History, Music" have lower average numbers of votes, suggesting they might be less popular among viewers.
#
# * It's important to note that the number of votes is an indication of a movie's popularity and audience engagement.  However, the sample size for each genre combination may vary, which can affect the average number of votes.

# %% [markdown]
# ##**Expert Crew Selection per Genre**

# %% [markdown]
# To gain deeper insights into audience preferences, I will analyze the directors involved in the making of top-rated movies. Understanding the key contributors to successful films within specific genres can guide Microsoft in selecting the right directors for future movie projects. By aligning the expertise of these professionals with audience preferences, Microsoft can enhance the chances of producing successful movies that cater to the specific tastes of the target audience.

# %% [markdown]
# I will start by creating a df that stores all genres that have average rating of 7.0 and above:

# %%
# Filter movies with genres that have an average rating greater than 7.0
high_rated_genres_df = movie_ratings_df.groupby('genres')['averagerating'].mean().reset_index()
high_rated_genres_df = high_rated_genres_df[high_rated_genres_df['averagerating'] > 7.0]

# Merge with the movie_ratings_df to get the tconst and primary_title
top_rated_movies_df = movie_ratings_df.merge(high_rated_genres_df[['genres']], on='genres', how='inner')

# Select only the necessary columns
top_rated_movies_df = top_rated_movies_df[['tconst', 'genres', 'primary_title', 'start_year']]

top_rated_movies_df
# Out:
#           tconst                     genres  \
# 0      tt0159369                Documentary
# 1      tt0170651                Documentary
# 2      tt0262218                Documentary
# 3      tt0285423                Documentary
# 4      tt0417750                Documentary
# ...          ...                        ...
# 17880  tt7957456   Action,Adventure,Musical
# 17881  tt8305366  Adventure,Animation,Crime
# 17882  tt8318556   History,Mystery,Thriller
# 17883  tt8413518     Musical,Mystery,Sci-Fi
# 17884  tt9060598                Drama,Short
#
#                                            primary_title  start_year
# 0                     Cooper and Hemingway: The True Gen        2013
# 1                                   T.G.M. - osvoboditel        2018
# 2                                      Akakis mogzauroba        2012
# 3                                               Abolição        2019
# 4                              Hempsters: Plant the Seed        2010
# ...                                                  ...         ...
# 17880                               L'impasse. La route.        2018
# 17881  The Jester's Plane: A Curious Journey Down the...        2018
# 17882                          141 A.D. Mission in Dacia        2018
# 17883                                     Commanding Cue        2019
# 17884                                         Requiescat        2018
#
# [17885 rows x 4 columns]

# %% [markdown]
# To identify the directors who have had multiple 7.0+ ratings in their work, I will first join the top_rated_movies_df with a DataFrame that contains information about movie crew, including directors.

# %% [markdown]
# **`DATASET FIVE: imdb.title.principals.csv`**

# %%
# Read into the imdb.title.principles
crew_df = pd.read_csv('/content/imdb.title.principals.csv')
crew_df.head(20)
# Out:
#        tconst  ordering     nconst         category       job  \
# 0   tt0111414         1  nm0246005            actor       NaN
# 1   tt0111414         2  nm0398271         director       NaN
# 2   tt0111414         3  nm3739909         producer  producer
# 3   tt0323808        10  nm0059247           editor       NaN
# 4   tt0323808         1  nm3579312          actress       NaN
# 5   tt0323808         2  nm2694680            actor       NaN
# 6   tt0323808         3  nm0574615            actor       NaN
# 7   tt0323808         4  nm0502652          actress       NaN
# 8   tt0323808         5  nm0362736         director       NaN
# 9   tt0323808         6  nm0811056         producer  producer
# 10  tt0323808         7  nm0914939         producer  producer
# 11  tt0323808         8  nm0779346         composer       NaN
# 12  tt0323808         9  nm0676104  cinematographer       NaN
# 13  tt0417610        10  nm0284261         composer       NaN
# 14  tt0417610         1  nm0532721            actor       NaN
# 15  tt0417610         2  nm0330974          actress       NaN
# 16  tt0417610         3  nm0069209            actor       NaN
# 17  tt0417610         4  nm0679167          actress       NaN
# 18  tt0417610         5  nm1145057         director       NaN
# 19  tt0417610         6  nm0083201           writer     story
#
#                   characters
# 0                ["The Man"]
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4           ["Beth Boothby"]
# 5          ["Steve Thomson"]
# 6   ["Sir Lachlan Morrison"]
# 7    ["Lady Delia Morrison"]
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                 ["Lucio"]
# 15                 ["Diana"]
# 16         ["Dr. Samaniego"]
# 17         ["Adriana María"]
# 18                       NaN
# 19                       NaN

# %%
# Understand the structure of crew_df
crew_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   tconst      1028186 non-null  object
#  1   ordering    1028186 non-null  int64
#  2   nconst      1028186 non-null  object
#  3   category    1028186 non-null  object
#  4   job         177684 non-null   object
#  5   characters  393360 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB

# %% [markdown]
# Observation:
#
# There are missing values in the job and characters column. After inspecting the df and based off of the analysis we want to compute, we do not need the job, characters and ordering columns. We shall drop these columns.

# %%
# Drop the unnecessary columns and confirm the drop
crew_df = crew_df.drop(['job', 'characters', 'ordering'], axis=1)

crew_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 3 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   tconst    1028186 non-null  object
#  1   nconst    1028186 non-null  object
#  2   category  1028186 non-null  object
# dtypes: object(3)
# memory usage: 23.5+ MB

# %% [markdown]
# The remaining columns are well structured with no missing values. Now we can join the top_rated_movies_df to get the producers, directors and script writers of those movies that scored > 7.0 in ratings.

# %%
# Merge crew_df and top_rated_movies_df using the 'tconst' column
crew_top_movies_df = top_rated_movies_df.merge(crew_df, on='tconst', how='left')

crew_top_movies_df
# Out:
#            tconst       genres                       primary_title  \
# 0       tt0159369  Documentary  Cooper and Hemingway: The True Gen
# 1       tt0159369  Documentary  Cooper and Hemingway: The True Gen
# 2       tt0159369  Documentary  Cooper and Hemingway: The True Gen
# 3       tt0159369  Documentary  Cooper and Hemingway: The True Gen
# 4       tt0159369  Documentary  Cooper and Hemingway: The True Gen
# ...           ...          ...                                 ...
# 122698  tt9060598  Drama,Short                          Requiescat
# 122699  tt9060598  Drama,Short                          Requiescat
# 122700  tt9060598  Drama,Short                          Requiescat
# 122701  tt9060598  Drama,Short                          Requiescat
# 122702  tt9060598  Drama,Short                          Requiescat
#
#         start_year     nconst         category
# 0             2013  nm1347778           editor
# 1             2013  nm0001832            actor
# 2             2013  nm0137230            actor
# 3             2013  nm0186908          actress
# 4             2013  nm0000018             self
# ...            ...        ...              ...
# 122698        2018  nm1761332         director
# 122699        2018  nm4991212         producer
# 122700        2018  nm2401787         composer
# 122701        2018  nm3517217  cinematographer
# 122702        2018  nm0534509           editor
#
# [122703 rows x 6 columns]

# %%
crew_top_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 122703 entries, 0 to 122702
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         122703 non-null  object
#  1   genres         122703 non-null  object
#  2   primary_title  122703 non-null  object
#  3   start_year     122703 non-null  int64
#  4   nconst         122662 non-null  object
#  5   category       122662 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 6.6+ MB

# %% [markdown]
# Here we notice that the number of rows have reduced from 1,028,186 to 122703. This is because the rows have reduced to fit the top_rated_movies_df that had 17,885 rows. It is important to note that crew_top_movies have multiple entries per movie because each move has extra rows to fit in the crew members details.
#
# There are missing values in the nconst and category columns, we will therefore handle them before proceeding with analysis.

# %%
# Find % of missing values in crew_top_movies_df
crew_top_movies_df.isna().mean() *100
# Out:
# tconst           0.000000
# genres           0.000000
# primary_title    0.000000
# start_year       0.000000
# nconst           0.033414
# category         0.033414
# dtype: float64

# %% [markdown]
# We shall drop the missing values as they contribute to very little to the dataset.

# %%
# Drop missing values and confirm the drop
crew_top_movies_df = crew_top_movies_df.dropna()
crew_top_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 122662 entries, 0 to 122702
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         122662 non-null  object
#  1   genres         122662 non-null  object
#  2   primary_title  122662 non-null  object
#  3   start_year     122662 non-null  int64
#  4   nconst         122662 non-null  object
#  5   category       122662 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 6.6+ MB

# %%
# Understand the staff in the crew_top_movies_df
crew_top_movies_df['category'].value_counts()
# Out:
# self                   30500
# director               20090
# producer               15326
# cinematographer        13012
# composer               11658
# editor                 11215
# actor                  10002
# writer                  5319
# actress                 3357
# archive_footage         1893
# production_designer      283
# archive_sound              7
# Name: category, dtype: int64

# %% [markdown]
# We shall narrow down the category column to remain with the directors as key staff during a movie production.

# %%
# Remain with director and confirm changes
staff_needed = ['director']
crew_top_movies_df = crew_top_movies_df[crew_top_movies_df['category'].isin(staff_needed)]
crew_top_movies_df['category'].value_counts()
# Out:
# director    20090
# Name: category, dtype: int64

# %% [markdown]
# It is clear here we only have the titles of the primary staff in movie production. We need to get the names of these brilliant movie production professionals and be able to handpick them for the various genres we might want to start our movie projects on. We will find a dataset with these values.

# %% [markdown]
# **`DATASET FIVE: name.basics.tsv`**

# %%
# Read the file file with crew names
crew_names_df = pd.read_csv('/content/name.basics.tsv', delimiter='\t')
crew_names_df.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0072308,tt0053137,tt0050419,tt0031983
# 1  tt0117057,tt0075213,tt0038355,tt0037382
# 2  tt0054452,tt0057345,tt0056404,tt0049189
# 3  tt0078723,tt0077975,tt0072562,tt0080455
# 4  tt0083922,tt0069467,tt0050986,tt0050976

# %%
# Understand the structure of the df
crew_names_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6568285 entries, 0 to 6568284
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   nconst             object
#  1   primaryName        object
#  2   birthYear          object
#  3   deathYear          object
#  4   primaryProfession  object
#  5   knownForTitles     object
# dtypes: object(6)
# memory usage: 300.7+ MB

# %% [markdown]
# **Observation:**
#
# * This crew_names_df has the names I need for the key staff in movie productions. However some crew members are, unfortunately, not alive hence the death year column.
#
# * There is an no indication of presence of null values(if any) in the df. I need to find them manually.
#
# * After sorting these two things is when I will be able to join/merge crew_names_df and crew_top_rated using nconst with is the ID of the names of these crew members.

# %%
# Find % of missing values
crew_names_df.isna().mean() * 100
# Out:
# nconst                0.000000
# primaryName           0.000046
# birthYear             0.000000
# deathYear             0.000000
# primaryProfession    20.493173
# knownForTitles        0.000015
# dtype: float64

# %% [markdown]
# **Observation:**
#
# * The dataset has negligible missing values in the primaryName, birthYear, deathYear and knownForTitles. While primaryProfession has 20% missing values.
#
# * The use for the df is to join with crew_top_movies_df, I will not need columns; knownForTitles as we already have tconst and primaryProfession as I already have category, these are the two columns I will drop. Then drop all null values in the dataframe.

# %%
# Drop knownForTitles and primaryProfession columns and confirm drop
crew_names_df = crew_names_df.drop(columns = ['knownForTitles', 'primaryProfession'])
crew_names_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6568285 entries, 0 to 6568284
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   nconst       object
#  1   primaryName  object
#  2   birthYear    object
#  3   deathYear    object
# dtypes: object(4)
# memory usage: 200.4+ MB

# %%
# Drop missing values in the remaining components of the df and confirm there are no missing values
crew_names_df = crew_names_df.dropna()
crew_names_df.isna().sum()
# Out:
# nconst         0
# primaryName    0
# birthYear      0
# deathYear      0
# dtype: int64

# %% [markdown]
# The basic clean up is done and I do not need to retain the top crew members who are alive:

# %%
crew_names_df['deathYear'].value_counts()
# Out:
# \N      6387724
# 2021       4969
# 2020       4794
# 2022       4695
# 2019       3916
#          ...
# 1602          1
# 1630          1
# 1745          1
# 1595          1
# 1819          1
# Name: deathYear, Length: 423, dtype: int64

# %%
crew_names_df['birthYear'].value_counts()
# Out:
# \N      6139549
# 1970       6542
# 1978       6489
# 1974       6361
# 1976       6352
#          ...
# 1726          1
# 1493          1
# 1549          1
# 1586          1
# 1654          1
# Name: birthYear, Length: 474, dtype: int64

# %% [markdown]
# I now have a df we can use to merge with crew_top_movies_df.

# %%
# Merge crew_top_movies_df and crew_names_df using the nconst column
top_crew_names_df = crew_top_movies_df.merge(crew_names_df, on='nconst', how='inner')

top_crew_names_df.head()
# Out:
#       tconst               genres                         primary_title  \
# 0  tt0159369          Documentary    Cooper and Hemingway: The True Gen
# 1  tt0170651          Documentary                  T.G.M. - osvoboditel
# 2  tt0277964  Documentary,History  Prague: The Restless Heart of Europe
# 3  tt0262218          Documentary                     Akakis mogzauroba
# 4  tt0285423          Documentary                              Abolição
#
#    start_year     nconst  category       primaryName birthYear deathYear
# 0        2013  nm0611850  director   John Mulholland        \N        \N
# 1        2018  nm0161615  director    Vera Chytilová      1929      2014
# 2        2018  nm0161615  director    Vera Chytilová      1929      2014
# 3        2012  nm0024093  director  Vasil Amashukeli        \N        \N
# 4        2019  nm0119856  director     Zózimo Bulbul      1937      2013

# %%
# Understand the structure of top_crew_names_df
top_crew_names_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9851 entries, 0 to 9850
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         9851 non-null   object
#  1   genres         9851 non-null   object
#  2   primary_title  9851 non-null   object
#  3   start_year     9851 non-null   int64
#  4   nconst         9851 non-null   object
#  5   category       9851 non-null   object
#  6   primaryName    9851 non-null   object
#  7   birthYear      9851 non-null   object
#  8   deathYear      9851 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 769.6+ KB

# %% [markdown]
# Since that df is clean, I need to handle the dead crew members and remain with the ones that are alive.

# %%
# Find the value_counts of the deathYear column
top_crew_names_df['deathYear'].value_counts()
# Out:
# \N      9639
# 2019      31
# 2022      24
# 2021      23
# 2014      23
# 2020      19
# 2018      17
# 2017      17
# 2013      10
# 2016      10
# 2015      10
# 2023      10
# 2011       7
# 2012       5
# 2010       1
# 2003       1
# 2006       1
# 2008       1
# 1994       1
# 2007       1
# Name: deathYear, dtype: int64

# %% [markdown]
# I can begin with removing all rows that are not /N as they are clear depiction of dead crew members. \N is just a representation of missing data used in this particular df.

# %%
# Remove the rows with actual years and retain \N and confirm the value_counts
top_crew_names_df = top_crew_names_df[top_crew_names_df['deathYear'] == '\\N']

top_crew_names_df['deathYear'].value_counts()
# Out:
# \N    9639
# Name: deathYear, dtype: int64

# %% [markdown]
# I can now explore the df and see how to find the crew members that are still alive.

# %%
# Check the df components
top_crew_names_df
# Out:
#          tconst                      genres  \
# 0     tt0159369                 Documentary
# 3     tt0262218                 Documentary
# 5     tt0417750                 Documentary
# 6     tt0430524                 Documentary
# 7     tt0436782                 Documentary
# ...         ...                         ...
# 9846  tt5234462  Adventure,Animation,Horror
# 9847  tt6035470        Animation,Sci-Fi,War
# 9848  tt7230298   Animation,Fantasy,Romance
# 9849  tt7342838     Biography,Music,Romance
# 9850  tt9060598                 Drama,Short
#
#                                       primary_title  start_year     nconst  \
# 0                Cooper and Hemingway: The True Gen        2013  nm0611850
# 3                                 Akakis mogzauroba        2012  nm0024093
# 5                         Hempsters: Plant the Seed        2010  nm0377412
# 6                                       The Rescuer        2011  nm0342041
# 7                   A Life in the Death of Joe Meek        2013  nm0074206
# ...                                             ...         ...        ...
# 9846                          Ajin Part 3: Shougeki        2016  nm1483822
# 9847   Mobile Suit Gundam Thunderbolt: December Sky        2016  nm2179963
# 9848  Meiji Tokyo Renka Movie: Yumihari no Serenade        2015  nm0913809
# 9849                                           Leto        2018  nm1970598
# 9850                                     Requiescat        2018  nm1761332
#
#       category           primaryName birthYear deathYear
# 0     director       John Mulholland        \N        \N
# 3     director      Vasil Amashukeli        \N        \N
# 5     director    Michael P. Henning        \N        \N
# 6     director            Leo Grillo      1949        \N
# 7     director      Howard S. Berger        \N        \N
# ...        ...                   ...       ...       ...
# 9846  director          Hiroaki Andô      1966        \N
# 9847  director             Kô Matsuo        \N        \N
# 9848  director      Hiroshi Watanabe        \N        \N
# 9849  director  Kirill Serebrennikov      1969        \N
# 9850  director         SJ Main Muñoz        \N        \N
#
# [9639 rows x 9 columns]

# %% [markdown]
# According to University of South Carolina research done in the film industry, the average age of male directors is (46.2 years) and female directors is (47.4 years) at the time of a film's release.

# %%
# Sort by birth year
top_crew_names_df = top_crew_names_df.sort_values(by = 'birthYear', ascending = True)
top_crew_names_df.head()
# Out:
#          tconst       genres                              primary_title  \
# 2141  tt2118032  Documentary                                   The Maze
# 4968  tt5247282  Documentary  Informe general II. El nou rapte d'Europa
# 5558  tt6151650  Documentary                   Mjesto sjecanja: Vukovar
# 817   tt8749146  Documentary                          Monrovia, Indiana
# 811   tt1653827  Documentary                                 Boxing Gym
#
#       start_year     nconst  category        primaryName birthYear deathYear
# 2141        2011  nm0950001  director    Robert M. Young      1924        \N
# 4968        2015  nm0691908  director    Pere Portabella      1927        \N
# 5558        2015  nm0119819  director     Veljko Bulajic      1928        \N
# 817         2018  nm0936464  director  Frederick Wiseman      1930        \N
# 811         2010  nm0936464  director  Frederick Wiseman      1930        \N

# %% [markdown]
# I still have birth years as early as 1906, meaning some \N values in deathYear are true missing values and some are for people who are alive.

# %%
# Get value counts of birth years
top_crew_names_df['birthYear'].value_counts()
# Out:
# \N      6415
# 1967     136
# 1970     135
# 1966     128
# 1964     113
#         ...
# 1933       1
# 1927       1
# 1991       1
# 2003       1
# 1924       1
# Name: birthYear, Length: 67, dtype: int64

# %% [markdown]
# To cater for unique ages, I shall filter top crew members who are currently under the age of 65 years.

# %%
# Filter the birth year to have only crew members that have birth years of 1959 and above.
top_crew_names_df = top_crew_names_df[(top_crew_names_df['birthYear'] >= '1959')]
top_crew_names_df['birthYear'].value_counts()
# Out:
# \N      6415
# 1967     136
# 1970     135
# 1966     128
# 1964     113
# 1969     112
# 1973     110
# 1972     104
# 1963     100
# 1965      97
# 1968      95
# 1959      92
# 1979      91
# 1975      89
# 1974      88
# 1971      84
# 1961      79
# 1977      77
# 1962      76
# 1976      75
# 1960      65
# 1978      60
# 1980      53
# 1981      46
# 1983      39
# 1984      31
# 1982      25
# 1986      13
# 1987      12
# 1985       9
# 1988       8
# 1989       4
# 1990       2
# 1991       1
# 2003       1
# Name: birthYear, dtype: int64

# %% [markdown]
# There are "\N" values in the birth year. However, it presents an opportunity to explore a new dataset from IMDB, containing the names of directors, which is part of a recently updated dataset.
#
# I have successfully obtained a dataset, movies.csv, comprising the top 250 movies, each with a rating of 8.0 and above. This dataset proves to be more suitable and promising for our analysis, providing a better foundation to work with as I delve deeper into find the world's top rated directors per genre.

# %% [markdown]
# **`DATASET FIVE: movies.csv`**

# %%
# Read movies.csv
directors_df = pd.read_csv('/content/movies.csv')
directors_df.head()
# Out:
#    rank         id                      name  year  imbd_votes  imdb_rating  \
# 0     1  tt0111161  The Shawshank Redemption  1994     2601152          9.3
# 1     2  tt0068646             The Godfather  1972     1796656          9.2
# 2     3  tt0468569           The Dark Knight  2008     2572662          9.0
# 3     4  tt0071562     The Godfather Part II  1974     1237934          9.0
# 4     5  tt0050083              12 Angry Men  1957      768548          9.0
#
#   certificate duration               genre  \
# 0           A      142               Drama
# 1           A      175         Crime,Drama
# 2          UA      152  Action,Crime,Drama
# 3           A      202         Crime,Drama
# 4           U       96         Crime,Drama
#
#                                              cast_id  \
# 0  nm0000209,nm0000151,nm0348409,nm0006669,nm0000...
# 1  nm0000008,nm0000199,nm0001001,nm0000473,nm0144...
# 2  nm0000288,nm0005132,nm0001173,nm0000323,nm0350...
# 3  nm0000199,nm0000134,nm0000380,nm0000473,nm0001...
# 4  nm0000020,nm0002011,nm0000842,nm0275835,nm0550...
#
#                                            cast_name director_id  \
# 0  Tim Robbins,Morgan Freeman,Bob Gunton,William ...   nm0001104
# 1  Marlon Brando,Al Pacino,James Caan,Diane Keato...   nm0000338
# 2  Christian Bale,Heath Ledger,Aaron Eckhart,Mich...   nm0634240
# 3  Al Pacino,Robert De Niro,Robert Duvall,Diane K...   nm0000338
# 4  Henry Fonda,Lee J. Cobb,Martin Balsam,John Fie...   nm0001486
#
#           director_name                                     writter_name  \
# 0        Frank Darabont                      Stephen King,Frank Darabont
# 1  Francis Ford Coppola                  Mario Puzo,Francis Ford Coppola
# 2     Christopher Nolan  Jonathan Nolan,Christopher Nolan,David S. Goyer
# 3  Francis Ford Coppola                  Francis Ford Coppola,Mario Puzo
# 4          Sidney Lumet                                    Reginald Rose
#
#                       writter_id  \
# 0            nm0000175,nm0001104
# 1            nm0701374,nm0000338
# 2  nm0634300,nm0634240,nm0275286
# 3            nm0000338,nm0701374
# 4                      nm0741627
#
#                                             img_link
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...

# %% [markdown]
# I will narrow this dataset down to movies released from the year 2000.

# %%
# Remain with movies produced from the year 2000
directors_df = directors_df[directors_df['year'] >= 2000]
directors_df.head(2)
# Out:
#    rank         id                                           name  year  \
# 2     3  tt0468569                                The Dark Knight  2008
# 6     7  tt0167260  The Lord of the Rings: The Return of the King  2003
#
#    imbd_votes  imdb_rating certificate duration                   genre  \
# 2     2572662          9.0          UA      152      Action,Crime,Drama
# 6     1786498          9.0           U      201  Action,Adventure,Drama
#
#                                              cast_id  \
# 2  nm0000288,nm0005132,nm0001173,nm0000323,nm0350...
# 6  nm0000704,nm0001557,nm0005212,nm0089217,nm0032...
#
#                                            cast_name director_id  \
# 2  Christian Bale,Heath Ledger,Aaron Eckhart,Mich...   nm0634240
# 6  Elijah Wood,Viggo Mortensen,Ian McKellen,Orlan...   nm0001392
#
#        director_name                                     writter_name  \
# 2  Christopher Nolan  Jonathan Nolan,Christopher Nolan,David S. Goyer
# 6      Peter Jackson        J.R.R. Tolkien,Fran Walsh,Philippa Boyens
#
#                       writter_id  \
# 2  nm0634300,nm0634240,nm0275286
# 6  nm0866058,nm0909638,nm0101991
#
#                                             img_link
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 6  https://m.media-amazon.com/images/M/MV5BOGM4ZT...

# %% [markdown]
# I will now drop the columns we do not need.

# %%
# Drop the unecessary columns and understand the df
directors_df = directors_df.drop(columns = ['rank', 'name' , 'id' ,'imbd_votes', 'year', 'imdb_rating', 'certificate', 'duration', 'cast_id', 'cast_name', 'director_id', 'writter_id', 'img_link'])
directors_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97 entries, 2 to 248
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   genre          97 non-null     object
#  1   director_name  97 non-null     object
#  2   writter_name   97 non-null     object
# dtypes: object(3)
# memory usage: 3.0+ KB

# %%
# View the df
directors_df.head()
# Out:
#                      genre                  director_name  \
# 22             Crime,Drama  Fernando Meirelles,Kátia Lund
# 26  Adventure,Drama,Sci-Fi              Christopher Nolan
# 32   Biography,Drama,Music                 Roman Polanski
# 40    Drama,Mystery,Sci-Fi              Christopher Nolan
# 43             Drama,Music                Damien Chazelle
#
#                                          writter_name
# 22                       Paulo Lins,Bráulio Mantovani
# 26                   Jonathan Nolan,Christopher Nolan
# 32                  Ronald Harwood,Wladyslaw Szpilman
# 40  Jonathan Nolan,Christopher Nolan,Christopher P...
# 43                                    Damien Chazelle

# %%
# Check for duplicates in genres
duplicated_genres = directors_df.duplicated()
print('Number of duplicate values:' , duplicated_genres.sum())
# Out:
# Number of duplicate values: 2

# %%
# Drop duplicated genres
directors_df = directors_df.drop_duplicates('genre', keep= False)

# %%
# View the df
directors_df
# Out:
#                          genre                  director_name  \
# 22                 Crime,Drama  Fernando Meirelles,Kátia Lund
# 26      Adventure,Drama,Sci-Fi              Christopher Nolan
# 32       Biography,Drama,Music                 Roman Polanski
# 40        Drama,Mystery,Sci-Fi              Christopher Nolan
# 43                 Drama,Music                Damien Chazelle
# 56               Drama,Western              Quentin Tarantino
# 70        Action,Drama,Mystery                 Park Chan-wook
# 77         Adventure,Drama,War              Quentin Tarantino
# 84     Animation,Drama,Fantasy                 Makoto Shinkai
# 86                Comedy,Drama                Rajkumar Hirani
# 89        Drama,Romance,Sci-Fi                  Michel Gondry
# 99              Comedy,Romance             Jean-Pierre Jeunet
# 116               Comedy,Crime                    Guy Ritchie
# 121           Action,Drama,War                     Sam Mendes
# 133     Biography,Comedy,Crime                Martin Scorsese
# 134    Action,Adventure,Comedy      Dan Kwan,Daniel Scheinert
# 139          Drama,Fantasy,War             Guillermo del Toro
# 142            Biography,Drama                     Ron Howard
# 163      Drama,Mystery,Romance           Juan José Campanella
# 166         Comedy,Crime,Drama                Martin McDonagh
# 169         Action,Drama,Sport                 Gavin O'Connor
# 173                Drama,Sport                 Clint Eastwood
# 186   Adventure,Fantasy,Horror                    David Yates
# 189     Adventure,Comedy,Crime                   Wes Anderson
# 203     Animation,Comedy,Drama                    Adam Elliot
# 218  Adventure,Biography,Drama                      Sean Penn
# 224              Drama,Romance              Richard Linklater
# 232     Biography,Drama,Family                Lasse Hallström
# 244     Drama,Romance,Thriller                 Park Chan-wook
#
#                                           writter_name
# 22                        Paulo Lins,Bráulio Mantovani
# 26                    Jonathan Nolan,Christopher Nolan
# 32                   Ronald Harwood,Wladyslaw Szpilman
# 40   Jonathan Nolan,Christopher Nolan,Christopher P...
# 43                                     Damien Chazelle
# 56                                   Quentin Tarantino
# 70     Garon Tsuchiya,Nobuaki Minegishi,Park Chan-wook
# 77                                   Quentin Tarantino
# 84                          Makoto Shinkai,Clark Cheng
# 86    Rajkumar Hirani,Abhijat Joshi,Vidhu Vinod Chopra
# 89        Charlie Kaufman,Michel Gondry,Pierre Bismuth
# 99                Guillaume Laurant,Jean-Pierre Jeunet
# 116                                        Guy Ritchie
# 121                    Sam Mendes,Krysty Wilson-Cairns
# 133                      Terence Winter,Jordan Belfort
# 134                          Dan Kwan,Daniel Scheinert
# 139                                 Guillermo del Toro
# 142                        Akiva Goldsman,Sylvia Nasar
# 163               Eduardo Sacheri,Juan José Campanella
# 166                                    Martin McDonagh
# 169      Gavin O'Connor,Anthony Tambakis,Cliff Dorfman
# 173                             Paul Haggis,F.X. Toole
# 186                          Steve Kloves,J.K. Rowling
# 189            Stefan Zweig,Wes Anderson,Hugo Guinness
# 203                                        Adam Elliot
# 218                             Sean Penn,Jon Krakauer
# 224          Richard Linklater,Julie Delpy,Ethan Hawke
# 232                   Stephen P. Lindsey,Kaneto Shindô
# 244       Sarah Waters,Seo-kyeong Jeong,Park Chan-wook

# %%
# Find the number of directors and writers
directors_df.shape
# Out:
# (29, 3)

# %% [markdown]
# **Observation:**
#
# * I have remained with directors and writers from 29 different genre combinations. This shall be converted into an spreadsheet and used to source these seasoned directors and writers.

# %% [markdown]
# #**CONCLUSION**
#
# * Microsoft can gain valuable insights by studying successful movie studios and adopting their effective marketing and production strategies to achieve success in the movie industry.
# * Blindly increasing movie production does not guarantee higher revenue; factors like film quality, marketing efforts, audience preferences, and industry competition are crucial determinants of revenue.
#
# #**RECOMMENDATION**
#
# * Microsoft should consider re-releasing classic movies or producing continued sequels, as audiences are receptive to revisiting such content, leading to increased revenue.
# * Focusing on popular genres during initial movie production will be essential to attract a wider viewership and ensure a successful entry into the industry.
# * Prioritizing movie quality over extravagant budgets by emphasizing compelling storytelling, well-crafted scripts, and collaboration with experienced directors and writers will resonate with audiences and elevate the cinematic experience.
# * Collaborating with seasoned industry professionals can create an environment that fosters creativity and innovation, setting the stage for remarkable cinematic achievements.
#
# By implementing these recommendations, Microsoft can overcome entry barriers in the movie industry and establish a robust presence, combining technological expertise with high-quality filmmaking to deliver captivating films that leave a lasting impact on audiences.
